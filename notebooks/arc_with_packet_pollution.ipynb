# %%
from binary_ext_fields.custom_field import TableField, create_field
from binary_ext_fields.generate_symbols import generate_symbols_random, check_orth, recode, check_orth_skip_coeffs, recode_rlnc, recode_rlnc_without_coeffs
from binary_ext_fields.orthogonal_tag_creator import OrthogonalTagGenerator as OTC

from utils.log_helpers import print_generation, to_int_matrx

from icecream import ic

# %% [markdown]
# ### Lets make a small arc test  with and without a pulluted packet
